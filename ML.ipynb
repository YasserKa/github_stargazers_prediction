# %%
# Using a local dataset
import json
import pandas as pd

with open('repos1/gistfile1.txt') as json_file:
    repos = json.load(json_file)

# %%
df_repos = pd.DataFrame.from_dict(repos).T #Transposing the dataframe column=>row, row=>column

# %%
df_repos.head(5)
# Out:
#                                             owner                   name  \
# kiang/pharmacies                            kiang             pharmacies
# rust-lang/crates.io-index               rust-lang        crates.io-index
# szczepienia/szczepienia.github.io     szczepienia  szczepienia.github.io
# 33kk/uso-archive                             33kk            uso-archive
# streetcomplete/StreetComplete      streetcomplete         StreetComplete
#
#                                              id  \
# kiang/pharmacies                   id_238189243
# rust-lang/crates.io-index           id_26193547
# szczepienia/szczepienia.github.io  id_357316184
# 33kk/uso-archive                   id_285580914
# streetcomplete/StreetComplete       id_62446262
#
#                                                            full_name  \
# kiang/pharmacies                                    kiang/pharmacies
# rust-lang/crates.io-index                  rust-lang/crates.io-index
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

#Random Forest
X = df_repos.drop(['owner', 'name', 'id', 'full_name', 'created_at', 'last_commit', 'stargazer_count'], axis=1)
y = df_repos['stargazer_count']
y = y.astype('int')

#sc = StandardScaler()
#X = sc.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
import numpy as np
from sklearn import metrics

rf = RandomForestRegressor(n_estimators=200, random_state = 42)
rf.fit(X_train, y_train)

training_score = rf.score(X_train, y_train)
test_score = rf.score(X_test, y_test)

print("training score: ", training_score)
print("test score: ", test_score)
# Out:
# training score:  0.9660450220392334
# test score:  0.8443708473279027
